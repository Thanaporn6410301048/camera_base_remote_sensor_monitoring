# %%
import cv2
import time
import time

# เปิดกล้องเว็บแคม (0 คือกล้องเริ่มต้น, ถ้ามีหลายกล้องอาจใช้ 1, 2, ...)
cap = cv2.VideoCapture(0)

# ตรวจสอบว่าเปิดกล้องสำเร็จหรือไม่
if not cap.isOpened():
    print("ไม่สามารถเปิดกล้องได้")
    exit()

print("กดปุ่มใดก็ได้เพื่อปิดโปรแกรม")

while True:
    # อ่านเฟรมจากกล้อง
    ret, frame = cap.read()

    # ตรวจสอบว่าอ่านเฟรมสำเร็จหรือไม่
    if not ret:
        print("ไม่สามารถรับภาพจากกล้องได้")
        break

    # แสดงเฟรมในหน้าต่าง 
    cv2.imshow('Webcam', frame)

    # รอรับคีย์บอร์ด ถ้ามีการกดปุ่มใดๆ ให้ออกจากลูป
    if cv2.waitKey(1) != -1:
        break

# ปล่อยทรัพยากรและปิดหน้าต่าง
cap.release()
cv2.destroyAllWindows()


# สร้างโฟลเดอร์สำหรับเก็บภาพถ่าย
if not os.path.exists('snapshots'):
    os.makedirs('snapshots')

# เปิดกล้องเว็บแคม
cap = cv2.VideoCapture(0)

# ตรวจสอบว่าเปิดกล้องสำเร็จหรือไม่
if not cap.isOpened():
    print("ไม่สามารถเปิดกล้องได้")
    exit()

print("กำลังถ่ายภาพทุก 2 วินาที... กดปุ่มใดก็ได้เพื่อปิดโปรแกรม")

shot_count = 0
last_shot_time = time.time()

while True:
    # อ่านเฟรมจากกล้อง
    ret, frame = cap.read()

    # ตรวจสอบว่าอ่านเฟรมสำเร็จหรือไม่
    if not ret:
        print("ไม่สามารถรับภาพจากกล้องได้")
        break

    # แสดงเฟรมในหน้าต่าง
    cv2.imshow('Webcam', frame)

    # ตรวจสอบเวลาและถ่ายภาพทุก 10 วินาที
    current_time = time.time()
    if current_time - last_shot_time >= 2:
        shot_count += 1
        filename = f'snapshots/shot_{shot_count}.jpg'
        cv2.imwrite(filename, frame)
        print(f"ถ่ายภาพ {filename}")
        last_shot_time = current_time

    # รอรับคีย์บอร์ด ถ้ามีการกดปุ่มใดๆ ให้ออกจากลูป
    if cv2.waitKey(1) != -1:
        break

# ปล่อยทรัพยากรและปิดหน้าต่าง
cap.release()
cv2.destroyAllWindows()

print(f"โปรแกรมจบการทำงาน ถ่ายภาพทั้งหมด {shot_count} ภาพ")
# Out:
# กดปุ่มใดก็ได้เพื่อปิดโปรแกรม
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 37
#      33 cv2.destroyAllWindows()
#      36 # สร้างโฟลเดอร์สำหรับเก็บภาพถ่าย
# ---> 37 if not os.path.exists('snapshots'):
#      38     os.makedirs('snapshots')
#      40 # เปิดกล้องเว็บแคม
#
# NameError: name 'os' is not defined

# %%
import cv2

# เปิดกล้องเว็บแคม (0 คือกล้องเริ่มต้น, ถ้ามีหลายกล้องอาจใช้ 1, 2, ...)
cap = cv2.VideoCapture(0)

# ตรวจสอบว่าเปิดกล้องสำเร็จหรือไม่
if not cap.isOpened():
    print("ไม่สามารถเปิดกล้องได้")
    exit()

print("กดปุ่มใดก็ได้เพื่อปิดโปรแกรม")

while True:
    # อ่านเฟรมจากกล้อง
    ret, frame = cap.read()

    # ตรวจสอบว่าอ่านเฟรมสำเร็จหรือไม่
    if not ret:
        print("ไม่สามารถรับภาพจากกล้องได้")
        break

    # แสดงเฟรมในหน้าต่าง 
    cv2.imshow('Webcam', frame)

    # รอรับคีย์บอร์ด ถ้ามีการกดปุ่มใดๆ ให้ออกจากลูป
    if cv2.waitKey(1) != -1:
        break

# ปล่อยทรัพยากรและปิดหน้าต่าง
cap.release()
cv2.destroyAllWindows()
# Out:
# กดปุ่มใดก็ได้เพื่อปิดโปรแกรม

# %%
import cv2
import time
import os

# สร้างโฟลเดอร์สำหรับเก็บภาพถ่าย
if not os.path.exists('snapshots'):
    os.makedirs('snapshots')

# เปิดกล้องเว็บแคม
cap = cv2.VideoCapture(0)

# ตรวจสอบว่าเปิดกล้องสำเร็จหรือไม่
if not cap.isOpened():
    print("ไม่สามารถเปิดกล้องได้")
    exit()

print("กำลังถ่ายภาพทุก 2 วินาที... กดปุ่มใดก็ได้เพื่อปิดโปรแกรม")

shot_count = 0
last_shot_time = time.time()

while True:
    # อ่านเฟรมจากกล้อง
    ret, frame = cap.read()

    # ตรวจสอบว่าอ่านเฟรมสำเร็จหรือไม่
    if not ret:
        print("ไม่สามารถรับภาพจากกล้องได้")
        break

    # แสดงเฟรมในหน้าต่าง
    cv2.imshow('Webcam', frame)

    # ตรวจสอบเวลาและถ่ายภาพทุก 10 วินาที
    current_time = time.time()
    if current_time - last_shot_time >= 2:
        shot_count += 1
        filename = f'snapshots/shot_{shot_count}.jpg'
        cv2.imwrite(filename, frame)
        print(f"ถ่ายภาพ {filename}")
        last_shot_time = current_time

    # รอรับคีย์บอร์ด ถ้ามีการกดปุ่มใดๆ ให้ออกจากลูป
    if cv2.waitKey(1) != -1:
        break

# ปล่อยทรัพยากรและปิดหน้าต่าง
cap.release()
cv2.destroyAllWindows()

print(f"โปรแกรมจบการทำงาน ถ่ายภาพทั้งหมด {shot_count} ภาพ")
# Out:
# กำลังถ่ายภาพทุก 2 วินาที... กดปุ่มใดก็ได้เพื่อปิดโปรแกรม
# ถ่ายภาพ snapshots/shot_1.jpg
# ถ่ายภาพ snapshots/shot_2.jpg
# ถ่ายภาพ snapshots/shot_3.jpg
# ถ่ายภาพ snapshots/shot_4.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 44
#      41         last_shot_time = current_time
#      43     # รอรับคีย์บอร์ด ถ้ามีการกดปุ่มใดๆ ให้ออกจากลูป
# ---> 44     if cv2.waitKey(1) != -1:
#      45         break
#      47 # ปล่อยทรัพยากรและปิดหน้าต่าง
#
# KeyboardInterrupt:

# %%
import cv2
import time
import os

# กำหนดขนาดของ checkerboard (จำนวนจุดในแนวนอน x แนวตั้ง)
CHECKERBOARD = (9, 6)  # ปรับค่าตามขนาดจริงของ checkerboard ที่ใช้

# สร้างโฟลเดอร์สำหรับเก็บภาพถ้าไม่มีอยู่
output_dir = 'snapshots/snapshot_img'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# เปิดการเชื่อมต่อกับกล้องเว็บแคม
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("ไม่สามารถเปิดกล้องได้")
    exit()

img_counter = 0
start_time = time.time()

try:
    while img_counter < 30:
        ret, frame = cap.read()

        if not ret:
            print("ไม่สามารถอ่านภาพจากกล้องได้")
            break

        # ตรวจจับ checkerboard
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        ret, corners = cv2.findChessboardCorners(gray, CHECKERBOARD, None)

        if ret:
            # วาดเส้นที่ตรวจจับได้ลงในภาพ
            cv2.drawChessboardCorners(frame, CHECKERBOARD, corners, ret)
            # แสดงจำนวนมุมที่ตรวจจับได้
            cv2.putText(frame, f"Detected: {len(corners)} corners", (10, 30), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # บันทึกภาพทุกๆ 1 วินาที
            if time.time() - start_time >= 1:
                img_name = f"{output_dir}/snapshot_{img_counter}.png"
                cv2.imwrite(img_name, frame)
                print(f"บันทึกภาพ {img_name} แล้ว")
                img_counter += 1
                start_time = time.time()

        # แสดงภาพจากกล้อง
        cv2.imshow("Webcam Feed with Checkerboard Detection", frame)

        # หยุดการทำงานด้วยการกด 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

except KeyboardInterrupt:
    print("หยุดการทำงาน")

finally:
    cap.release()
    cv2.destroyAllWindows()
# Out:
# บันทึกภาพ snapshots/snapshot_img/snapshot_0.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_1.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_2.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_3.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_4.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_5.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_6.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_7.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_8.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_9.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_10.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_11.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_12.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_13.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_14.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_15.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_16.png แล้ว
# บันทึกภาพ snapshots/snapshot_img/snapshot_17.png แล้ว
# ...
